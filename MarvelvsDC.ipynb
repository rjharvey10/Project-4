# %% [markdown]
# ### Insert Dependencies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read CSV Files

# %%
df_marvel = pd.read_csv('data/marvel-wikia-data.csv')
df_dc = pd.read_csv('data/dc-wikia-data.csv')

# %%
df_marvel.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %%
df_dc.head()
# Out:
#    page_id                         name                              urlslug  \
# 0     1422         Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 1    23387        Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 2     1458   Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 3     1659     James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 4     1576  Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                 ID            ALIGN         EYE        HAIR              SEX  \
# 0  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 1  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 2  Secret Identity  Good Characters  Brown Eyes  Brown Hair  Male Characters
# 3  Public Identity  Good Characters  Brown Eyes  White Hair  Male Characters
# 4  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
#
#    GSM              ALIVE  APPEARANCES FIRST APPEARANCE    YEAR
# 0  NaN  Living Characters       3093.0        1939, May  1939.0
# 1  NaN  Living Characters       2496.0    1986, October  1986.0
# 2  NaN  Living Characters       1565.0    1959, October  1959.0
# 3  NaN  Living Characters       1316.0   1987, February  1987.0
# 4  NaN  Living Characters       1237.0      1940, April  1940.0

# %%
# Identify total rows and columns in dataframe
print(df_marvel.shape)
print(df_dc.shape)
# Out:
# (16376, 13)
# (6896, 13)

# %% [markdown]
# ### Marvel Data Clean

# %%
# Remove unnecessary columns 
df_marvel_dropped = df_marvel.drop(columns = ['page_id', 'urlslug', 'ALIVE', 'FIRST APPEARANCE'])
df_marvel_dropped.head()
# Out:
#                                   name                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX  GSM  APPEARANCES    Year
# 0  Hazel Eyes  Brown Hair  Male Characters  NaN       4043.0  1962.0
# 1   Blue Eyes  White Hair  Male Characters  NaN       3360.0  1941.0
# 2   Blue Eyes  Black Hair  Male Characters  NaN       3061.0  1974.0
# 3   Blue Eyes  Black Hair  Male Characters  NaN       2961.0  1963.0
# 4   Blue Eyes  Blond Hair  Male Characters  NaN       2258.0  1950.0

# %%
# Rename 'Name' and 'Year' columns 
df_marvel_dropped = df_marvel_dropped.rename(columns={'name':'NAME','Year':'YEAR'})
df_marvel_dropped.head()
# Out:
#                                   NAME                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Hazel Eyes  Brown Hair  Male Characters  NaN       4043.0  1962.0
# 1   Blue Eyes  White Hair  Male Characters  NaN       3360.0  1941.0
# 2   Blue Eyes  Black Hair  Male Characters  NaN       3061.0  1974.0
# 3   Blue Eyes  Black Hair  Male Characters  NaN       2961.0  1963.0
# 4   Blue Eyes  Blond Hair  Male Characters  NaN       2258.0  1950.0

# %%
df_marvel_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME         16376 non-null  object
#  1   ID           12606 non-null  object
#  2   ALIGN        13564 non-null  object
#  3   EYE          6609 non-null   object
#  4   HAIR         12112 non-null  object
#  5   SEX          15522 non-null  object
#  6   GSM          90 non-null     object
#  7   APPEARANCES  15280 non-null  float64
#  8   YEAR         15561 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 1.1+ MB

# %%
# Identify mode
marvel_mode_id = df_marvel_dropped["ID"].mode().values[0]
marvel_mode_id
# Out:
# 'Secret Identity'

# %%
# Fill in null values in 'ID' with the mode 'Secret Identity'
df_marvel_dropped["ID"] = df_marvel_dropped["ID"].fillna(marvel_mode_id)
df_marvel_dropped.head()
# Out:
#                                   NAME                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Hazel Eyes  Brown Hair  Male Characters  NaN       4043.0  1962.0
# 1   Blue Eyes  White Hair  Male Characters  NaN       3360.0  1941.0
# 2   Blue Eyes  Black Hair  Male Characters  NaN       3061.0  1974.0
# 3   Blue Eyes  Black Hair  Male Characters  NaN       2961.0  1963.0
# 4   Blue Eyes  Blond Hair  Male Characters  NaN       2258.0  1950.0

# %%
# Drop null values from the column 'Align'
df_marvel_dropped = df_marvel_dropped.dropna(subset=['ALIGN'])

# %%
# Identify mode
marvel_mode_eye = df_marvel_dropped["EYE"].mode().values[0]
marvel_mode_eye
# Out:
# 'Blue Eyes'

# %%
# Fill in null values in 'EYE' with the mode 'Blue Eyes'
df_marvel_dropped["EYE"] = df_marvel_dropped["EYE"].fillna(marvel_mode_eye)
df_marvel_dropped.head()
# Out:
#                                   NAME                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Hazel Eyes  Brown Hair  Male Characters  NaN       4043.0  1962.0
# 1   Blue Eyes  White Hair  Male Characters  NaN       3360.0  1941.0
# 2   Blue Eyes  Black Hair  Male Characters  NaN       3061.0  1974.0
# 3   Blue Eyes  Black Hair  Male Characters  NaN       2961.0  1963.0
# 4   Blue Eyes  Blond Hair  Male Characters  NaN       2258.0  1950.0

# %%
# Identify mode
marvel_mode_hair = df_marvel_dropped["HAIR"].mode().values[0]
marvel_mode_hair
# Out:
# 'Black Hair'

# %%
# Fill in null values in 'HAIR' with the mode 'Black Hair'
df_marvel_dropped["HAIR"] = df_marvel_dropped["HAIR"].fillna(marvel_mode_hair)
df_marvel_dropped.head()
# Out:
#                                   NAME                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Hazel Eyes  Brown Hair  Male Characters  NaN       4043.0  1962.0
# 1   Blue Eyes  White Hair  Male Characters  NaN       3360.0  1941.0
# 2   Blue Eyes  Black Hair  Male Characters  NaN       3061.0  1974.0
# 3   Blue Eyes  Black Hair  Male Characters  NaN       2961.0  1963.0
# 4   Blue Eyes  Blond Hair  Male Characters  NaN       2258.0  1950.0

# %%
# Fill null values in 'SEX' column with 'Unknown'
df_marvel_dropped["SEX"] = df_marvel_dropped["SEX"].fillna("Unknown")

# %%
# Fill null values in 'GSM' column with 'Heterosexual'
df_marvel_dropped["GSM"] = df_marvel_dropped["GSM"].fillna('Heterosexual')

# %%
# Drop null values in the 'APPEARANCES' column
df_marvel_dropped = df_marvel_dropped.dropna(subset=['APPEARANCES'])

# %%
# Change 'APPEARANCES' from float to an integer
df_marvel_dropped['APPEARANCES'] = df_marvel_dropped['APPEARANCES'].astype(np.int64)

# %%
# Drop null values in the 'YEAR' column
df_marvel_dropped = df_marvel_dropped.dropna(subset=['YEAR'])

# %%
# Change 'YEAR' from float to an integer
df_marvel_dropped['YEAR'] = df_marvel_dropped['YEAR'].astype(np.int64)

# %%
df_marvel_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12206 entries, 0 to 15038
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME         12206 non-null  object
#  1   ID           12206 non-null  object
#  2   ALIGN        12206 non-null  object
#  3   EYE          12206 non-null  object
#  4   HAIR         12206 non-null  object
#  5   SEX          12206 non-null  object
#  6   GSM          12206 non-null  object
#  7   APPEARANCES  12206 non-null  int64
#  8   YEAR         12206 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 953.6+ KB

# %% [markdown]
# ### DC Data Clean

# %%
# Remove unnecessary columns
df_dc_dropped = df_dc.drop(columns = ['page_id', 'urlslug', 'ALIVE','FIRST APPEARANCE'])
df_dc_dropped.head()
# Out:
#                           name               ID            ALIGN         EYE  \
# 0         Batman (Bruce Wayne)  Secret Identity  Good Characters   Blue Eyes
# 1        Superman (Clark Kent)  Secret Identity  Good Characters   Blue Eyes
# 2   Green Lantern (Hal Jordan)  Secret Identity  Good Characters  Brown Eyes
# 3     James Gordon (New Earth)  Public Identity  Good Characters  Brown Eyes
# 4  Richard Grayson (New Earth)  Secret Identity  Good Characters   Blue Eyes
#
#          HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Black Hair  Male Characters  NaN       3093.0  1939.0
# 1  Black Hair  Male Characters  NaN       2496.0  1986.0
# 2  Brown Hair  Male Characters  NaN       1565.0  1959.0
# 3  White Hair  Male Characters  NaN       1316.0  1987.0
# 4  Black Hair  Male Characters  NaN       1237.0  1940.0

# %%
# Rename columns 
df_dc_dropped = df_dc_dropped.rename(columns={'name':'NAME'})
df_dc_dropped.head()
# Out:
#                           NAME               ID            ALIGN         EYE  \
# 0         Batman (Bruce Wayne)  Secret Identity  Good Characters   Blue Eyes
# 1        Superman (Clark Kent)  Secret Identity  Good Characters   Blue Eyes
# 2   Green Lantern (Hal Jordan)  Secret Identity  Good Characters  Brown Eyes
# 3     James Gordon (New Earth)  Public Identity  Good Characters  Brown Eyes
# 4  Richard Grayson (New Earth)  Secret Identity  Good Characters   Blue Eyes
#
#          HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Black Hair  Male Characters  NaN       3093.0  1939.0
# 1  Black Hair  Male Characters  NaN       2496.0  1986.0
# 2  Brown Hair  Male Characters  NaN       1565.0  1959.0
# 3  White Hair  Male Characters  NaN       1316.0  1987.0
# 4  Black Hair  Male Characters  NaN       1237.0  1940.0

# %%
df_dc_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6896 entries, 0 to 6895
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME         6896 non-null   object
#  1   ID           4883 non-null   object
#  2   ALIGN        6295 non-null   object
#  3   EYE          3268 non-null   object
#  4   HAIR         4622 non-null   object
#  5   SEX          6771 non-null   object
#  6   GSM          64 non-null     object
#  7   APPEARANCES  6541 non-null   float64
#  8   YEAR         6827 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 485.0+ KB

# %%
# Identify mode
mode_id = df_dc_dropped["ID"].mode().values[0]
mode_id
# Out:
# 'Public Identity'

# %%
# Fill in null values in 'ID' with the mode 'Public Identity'
df_dc_dropped["ID"] = df_dc_dropped["ID"].fillna(mode_id)
df_dc_dropped.head()
# Out:
#                           NAME               ID            ALIGN         EYE  \
# 0         Batman (Bruce Wayne)  Secret Identity  Good Characters   Blue Eyes
# 1        Superman (Clark Kent)  Secret Identity  Good Characters   Blue Eyes
# 2   Green Lantern (Hal Jordan)  Secret Identity  Good Characters  Brown Eyes
# 3     James Gordon (New Earth)  Public Identity  Good Characters  Brown Eyes
# 4  Richard Grayson (New Earth)  Secret Identity  Good Characters   Blue Eyes
#
#          HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Black Hair  Male Characters  NaN       3093.0  1939.0
# 1  Black Hair  Male Characters  NaN       2496.0  1986.0
# 2  Brown Hair  Male Characters  NaN       1565.0  1959.0
# 3  White Hair  Male Characters  NaN       1316.0  1987.0
# 4  Black Hair  Male Characters  NaN       1237.0  1940.0

# %%
df_dc_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6896 entries, 0 to 6895
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME         6896 non-null   object
#  1   ID           6896 non-null   object
#  2   ALIGN        6295 non-null   object
#  3   EYE          3268 non-null   object
#  4   HAIR         4622 non-null   object
#  5   SEX          6771 non-null   object
#  6   GSM          64 non-null     object
#  7   APPEARANCES  6541 non-null   float64
#  8   YEAR         6827 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 485.0+ KB

# %%
# Drop null values from the column 'Align'
df_dc_dropped = df_dc_dropped.dropna(subset=['ALIGN'])

# %%
# Identify mode
mode_eye = df_dc_dropped["EYE"].mode().values[0]
mode_eye
# Out:
# 'Blue Eyes'

# %%
# Fill in null values in 'EYE' with the mode 'Blue Eyes'
df_dc_dropped["EYE"] = df_dc_dropped["EYE"].fillna(mode_eye)
df_dc_dropped.head()
# Out:
#                           NAME               ID            ALIGN         EYE  \
# 0         Batman (Bruce Wayne)  Secret Identity  Good Characters   Blue Eyes
# 1        Superman (Clark Kent)  Secret Identity  Good Characters   Blue Eyes
# 2   Green Lantern (Hal Jordan)  Secret Identity  Good Characters  Brown Eyes
# 3     James Gordon (New Earth)  Public Identity  Good Characters  Brown Eyes
# 4  Richard Grayson (New Earth)  Secret Identity  Good Characters   Blue Eyes
#
#          HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Black Hair  Male Characters  NaN       3093.0  1939.0
# 1  Black Hair  Male Characters  NaN       2496.0  1986.0
# 2  Brown Hair  Male Characters  NaN       1565.0  1959.0
# 3  White Hair  Male Characters  NaN       1316.0  1987.0
# 4  Black Hair  Male Characters  NaN       1237.0  1940.0

# %%
# Identify mode
mode_hair = df_dc_dropped["HAIR"].mode().values[0]
mode_hair
# Out:
# 'Black Hair'

# %%
# Fill in null values in 'HAIR' with the mode 'Black Hair'
df_dc_dropped["HAIR"] = df_dc_dropped["HAIR"].fillna(mode_hair)
df_dc_dropped.head()
# Out:
#                           NAME               ID            ALIGN         EYE  \
# 0         Batman (Bruce Wayne)  Secret Identity  Good Characters   Blue Eyes
# 1        Superman (Clark Kent)  Secret Identity  Good Characters   Blue Eyes
# 2   Green Lantern (Hal Jordan)  Secret Identity  Good Characters  Brown Eyes
# 3     James Gordon (New Earth)  Public Identity  Good Characters  Brown Eyes
# 4  Richard Grayson (New Earth)  Secret Identity  Good Characters   Blue Eyes
#
#          HAIR              SEX  GSM  APPEARANCES    YEAR
# 0  Black Hair  Male Characters  NaN       3093.0  1939.0
# 1  Black Hair  Male Characters  NaN       2496.0  1986.0
# 2  Brown Hair  Male Characters  NaN       1565.0  1959.0
# 3  White Hair  Male Characters  NaN       1316.0  1987.0
# 4  Black Hair  Male Characters  NaN       1237.0  1940.0

# %%
# Fill null values in 'SEX' column with 'Unknown'
df_dc_dropped["SEX"] = df_dc_dropped["SEX"].fillna("Unknown")

# %%
# Fill null values in 'GSM' column with 'Heterosexual'
df_dc_dropped["GSM"] = df_dc_dropped["GSM"].fillna('Heterosexual')

# %%
# Drop null values in the 'APPEARANCES' column
df_dc_dropped = df_dc_dropped.dropna(subset=['APPEARANCES'])

# %%
# Change 'APPEARANCES' from float to an integer
df_dc_dropped['APPEARANCES'] = df_dc_dropped['APPEARANCES'].astype(np.int64)

# %%
# Drop null values in the 'YEAR' column
df_dc_dropped = df_dc_dropped.dropna(subset=['YEAR'])

# %%
# Change 'YEAR' from float to an integer
df_dc_dropped['YEAR'] = df_dc_dropped['YEAR'].astype(np.int64)

# %%
# Run df.info to see if dataframe is competle
df_dc_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5923 entries, 0 to 6529
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME         5923 non-null   object
#  1   ID           5923 non-null   object
#  2   ALIGN        5923 non-null   object
#  3   EYE          5923 non-null   object
#  4   HAIR         5923 non-null   object
#  5   SEX          5923 non-null   object
#  6   GSM          5923 non-null   object
#  7   APPEARANCES  5923 non-null   int64
#  8   YEAR         5923 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 462.7+ KB

# %%
print(df_marvel_dropped.shape)
print(df_dc_dropped.shape)
# Out:
# (12206, 9)
# (5923, 9)

# %%
df_marvel_dropped["STUDIO"] = "MARVEL"
df_dc_dropped["STUDIO"] = "DC"

# %%
### Concatenate both datasets into one
final_df = pd.concat([df_marvel_dropped,df_dc_dropped])
final_df
# Out:
#                                      NAME                ID  \
# 0               Spider-Man (Peter Parker)   Secret Identity
# 1         Captain America (Steven Rogers)   Public Identity
# 2     Wolverine (James \"Logan\" Howlett)   Public Identity
# 3       Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                     Thor (Thor Odinson)  No Dual Identity
# ...                                   ...               ...
# 6523          Carnie Callahan (New Earth)   Public Identity
# 6525         Frederick Devere (New Earth)   Public Identity
# 6526           Green Arrow (Oliver Queen)   Secret Identity
# 6528             Robert Mason (New Earth)   Secret Identity
# 6529         Diablo the Horse (New Earth)   Public Identity
#
#                    ALIGN         EYE        HAIR              SEX  \
# 0        Good Characters  Hazel Eyes  Brown Hair  Male Characters
# 1        Good Characters   Blue Eyes  White Hair  Male Characters
# 2     Neutral Characters   Blue Eyes  Black Hair  Male Characters
# 3        Good Characters   Blue Eyes  Black Hair  Male Characters
# 4        Good Characters   Blue Eyes  Blond Hair  Male Characters
# ...                  ...         ...         ...              ...
# 6523     Good Characters   Blue Eyes  Black Hair  Male Characters
# 6525      Bad Characters   Blue Eyes  Black Hair  Male Characters
# 6526     Good Characters  Green Eyes  Blond Hair  Male Characters
# 6528  Neutral Characters  Black Eyes  Black Hair  Male Characters
# 6529     Good Characters   Blue Eyes  Black Hair  Male Characters
#
#                GSM  APPEARANCES  YEAR  STUDIO
# 0     Heterosexual         4043  1962  MARVEL
# 1     Heterosexual         3360  1941  MARVEL
# 2     Heterosexual         3061  1974  MARVEL
# 3     Heterosexual         2961  1963  MARVEL
# 4     Heterosexual         2258  1950  MARVEL
# ...            ...          ...   ...     ...
# 6523  Heterosexual            1  1944      DC
# 6525  Heterosexual            1  1941      DC
# 6526  Heterosexual            1  1941      DC
# 6528  Heterosexual            1  1941      DC
# 6529  Heterosexual            1  1940      DC
#
# [18129 rows x 10 columns]

# %%
final_df.to_csv("final.csv")

# %%
url = "postgresql://jqzzrfsdewgljj:e5fb494866ce503b8bced245afe5c2068f1c7a94a9a242a8b41413def015f15c@ec2-54-157-16-196.compute-1.amazonaws.com:5432/d4k7shgqb7gn6i"

# %%
from sqlalchemy import create_engine
engine = create_engine(url)
final_df.to_sql('marveldc', engine, index=False)

# %%
test_df = pd.read_sql_table('marveldc', engine)

# %%
test_df
# Out:
#                                       NAME                ID  \
# 0                Spider-Man (Peter Parker)   Secret Identity
# 1          Captain America (Steven Rogers)   Public Identity
# 2      Wolverine (James \"Logan\" Howlett)   Public Identity
# 3        Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                      Thor (Thor Odinson)  No Dual Identity
# ...                                    ...               ...
# 18124          Carnie Callahan (New Earth)   Public Identity
# 18125         Frederick Devere (New Earth)   Public Identity
# 18126           Green Arrow (Oliver Queen)   Secret Identity
# 18127             Robert Mason (New Earth)   Secret Identity
# 18128         Diablo the Horse (New Earth)   Public Identity
#
#                     ALIGN         EYE        HAIR              SEX  \
# 0         Good Characters  Hazel Eyes  Brown Hair  Male Characters
# 1         Good Characters   Blue Eyes  White Hair  Male Characters
# 2      Neutral Characters   Blue Eyes  Black Hair  Male Characters
# 3         Good Characters   Blue Eyes  Black Hair  Male Characters
# 4         Good Characters   Blue Eyes  Blond Hair  Male Characters
# ...                   ...         ...         ...              ...
# 18124     Good Characters   Blue Eyes  Black Hair  Male Characters
# 18125      Bad Characters   Blue Eyes  Black Hair  Male Characters
# 18126     Good Characters  Green Eyes  Blond Hair  Male Characters
# 18127  Neutral Characters  Black Eyes  Black Hair  Male Characters
# 18128     Good Characters   Blue Eyes  Black Hair  Male Characters
#
#                 GSM  APPEARANCES  YEAR  STUDIO
# 0      Heterosexual         4043  1962  MARVEL
# 1      Heterosexual         3360  1941  MARVEL
# 2      Heterosexual         3061  1974  MARVEL
# 3      Heterosexual         2961  1963  MARVEL
# 4      Heterosexual         2258  1950  MARVEL
# ...             ...          ...   ...     ...
# 18124  Heterosexual            1  1944      DC
# 18125  Heterosexual            1  1941      DC
# 18126  Heterosexual            1  1941      DC
# 18127  Heterosexual            1  1941      DC
# 18128  Heterosexual            1  1940      DC
#
# [18129 rows x 10 columns]
